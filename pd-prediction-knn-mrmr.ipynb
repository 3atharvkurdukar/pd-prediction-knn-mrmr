# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import mifs

# %%
dataset = pd.read_csv('data/parkinsons.csv')

# %%
X = dataset.iloc[:, 1:-1]   # input feactures
y = dataset.iloc[:, -1]     # output
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0)

# %%
for i in range(1,22):
    feat_selector = mifs.MutualInformationFeatureSelector('MRMR',k=i)
    feat_selector.fit(X_train, y_train)
    # call transform() on X to filter it down to selected features
    X_filtered = feat_selector.transform(X_train.values)
    #Create list of features
    feature_name = X_train.columns[feat_selector.ranking_]
    print(feature_name)
# Out:
# Index(['spread1', 'PPE', 'MDVP:Fo(Hz)', 'MDVP:Flo(Hz)', 'spread2',
#        'Shimmer:DDA', 'MDVP:Fhi(Hz)', 'Shimmer:APQ3', 'MDVP:APQ', 'HNR',
#        'NHR'],
#       dtype='object')
# Index(['PPE', 'spread1'], dtype='object')
# Index(['PPE', 'MDVP:APQ', 'RPDE', 'DFA', 'MDVP:Jitter(%)', 'NHR',
#        'Shimmer:APQ5', 'Shimmer:DDA', 'MDVP:PPQ', 'Jitter:DDP', 'MDVP:Shimmer',
#        'spread1', 'spread2', 'D2', 'HNR', 'MDVP:Flo(Hz)', 'MDVP:Fhi(Hz)',
#        'MDVP:Fo(Hz)', 'Shimmer:APQ3', 'MDVP:RAP'],
#       dtype='object')
# Index(['PPE', 'MDVP:Shimmer', 'D2', 'HNR', 'spread2', 'RPDE', 'MDVP:Jitter(%)',
#        'spread1', 'NHR', 'MDVP:APQ', 'DFA'],
#       dtype='object')
# Index(['PPE', 'Shimmer:APQ3', 'DFA', 'D2', 'RPDE', 'spread2', 'NHR', 'HNR',
#        'MDVP:Fo(Hz)', 'Jitter:DDP', 'spread1', 'MDVP:APQ', 'MDVP:Flo(Hz)',
#        'Shimmer:DDA', 'MDVP:Shimmer(dB)', 'MDVP:PPQ', 'MDVP:Shimmer',
#        'MDVP:Jitter(%)', 'Shimmer:APQ5', 'MDVP:Fhi(Hz)', 'MDVP:RAP'],
#       dtype='object')
# Index(['MDVP:Fo(Hz)', 'HNR', 'D2', 'PPE', 'Shimmer:APQ3', 'DFA', 'NHR',
#        'spread2', 'Jitter:DDP', 'RPDE', 'spread1', 'MDVP:Shimmer(dB)',
#        'MDVP:APQ', 'MDVP:Flo(Hz)', 'Shimmer:APQ5', 'MDVP:PPQ', 'Shimmer:DDA',
#        'MDVP:Jitter(%)', 'MDVP:Fhi(Hz)', 'MDVP:Shimmer', 'MDVP:RAP'],
#       dtype='object')
# Index(['PPE', 'Jitter:DDP', 'DFA', 'MDVP:Shimmer(dB)', 'spread2', 'RPDE', 'D2',
#        'HNR', 'MDVP:Fo(Hz)', 'spread1', 'MDVP:APQ', 'NHR', 'Shimmer:DDA',
#        'MDVP:Flo(Hz)', 'MDVP:Shimmer', 'MDVP:PPQ', 'Shimmer:APQ5', 'MDVP:RAP',
#        'MDVP:Fhi(Hz)', 'Shimmer:APQ3', 'MDVP:Jitter(%)'],
#       dtype='object')
# Index(['PPE', 'Shimmer:APQ5', 'DFA', 'D2', 'HNR', 'MDVP:Fo(Hz)', 'NHR', 'RPDE',
#        'spread2', 'spread1', 'MDVP:Shimmer(dB)', 'MDVP:APQ', 'MDVP:RAP',
#        'MDVP:Flo(Hz)', 'Shimmer:DDA', 'MDVP:PPQ', 'MDVP:Shimmer',
#        'MDVP:Fhi(Hz)', 'Jitter:DDP', 'Shimmer:APQ3', 'MDVP:Jitter(%)'],
#       dtype='object')
# Index(['PPE', 'Shimmer:APQ5', 'NHR', 'D2', 'HNR', 'MDVP:Flo(Hz)', 'DFA',
#        'spread2', 'spread1', 'MDVP:Shimmer(dB)', 'RPDE', 'MDVP:APQ',
#        'MDVP:RAP', 'Shimmer:DDA', 'MDVP:Fhi(Hz)', 'MDVP:PPQ', 'Shimmer:APQ3',
#        'MDVP:Shimmer', 'MDVP:Jitter(%)', 'MDVP:Fo(Hz)', 'Jitter:DDP'],
#       dtype='object')
# Index(['PPE', 'Shimmer:APQ5', 'NHR', 'D2', 'HNR', 'MDVP:Flo(Hz)', 'DFA',
#        'MDVP:Shimmer(dB)', 'spread1', 'spread2', 'RPDE', 'MDVP:APQ',
#        'MDVP:RAP', 'Shimmer:DDA', 'MDVP:Fhi(Hz)', 'MDVP:PPQ', 'MDVP:Shimmer',
#        'Shimmer:APQ3', 'Jitter:DDP', 'MDVP:Jitter(%)', 'MDVP:Fo(Hz)'],
#       dtype='object')
# Index(['spread1', 'spread2', 'MDVP:APQ', 'DFA', 'PPE', 'D2',
#        'MDVP:Shimmer(dB)', 'HNR', 'MDVP:Flo(Hz)', 'NHR', 'MDVP:RAP', 'RPDE',
#        'Shimmer:APQ3', 'MDVP:Fhi(Hz)', 'MDVP:Shimmer', 'MDVP:PPQ',
#        'Shimmer:DDA', 'Shimmer:APQ5', 'Jitter:DDP', 'MDVP:Jitter(%)',
#        'MDVP:Fo(Hz)'],
#       dtype='object')
# Index(['spread1', 'MDVP:Shimmer(dB)', 'spread2', 'DFA', 'MDVP:APQ', 'PPE',
#        'D2', 'MDVP:RAP', 'NHR', 'RPDE', 'MDVP:Shimmer', 'HNR', 'MDVP:Flo(Hz)',
#        'MDVP:Fhi(Hz)', 'Shimmer:DDA', 'MDVP:PPQ', 'Shimmer:APQ5', 'Jitter:DDP',
#        'MDVP:Jitter(%)', 'Shimmer:APQ3', 'MDVP:Fo(Hz)'],
#       dtype='object')
# Index(['PPE', 'spread1', 'NHR', 'MDVP:PPQ', 'MDVP:Shimmer(dB)', 'D2', 'DFA',
#        'MDVP:APQ', 'spread2', 'RPDE', 'MDVP:Shimmer', 'HNR', 'MDVP:Flo(Hz)',
#        'MDVP:Fhi(Hz)', 'MDVP:RAP', 'Shimmer:DDA', 'Jitter:DDP', 'Shimmer:APQ5',
#        'MDVP:Jitter(%)', 'MDVP:Fo(Hz)', 'Shimmer:APQ3'],
#       dtype='object')
# Index(['spread1', 'PPE', 'NHR', 'MDVP:PPQ', 'MDVP:Shimmer(dB)', 'DFA', 'D2',
#        'spread2', 'MDVP:APQ', 'RPDE', 'HNR', 'MDVP:Flo(Hz)', 'MDVP:Fhi(Hz)',
#        'MDVP:Shimmer', 'MDVP:RAP', 'Shimmer:DDA', 'Jitter:DDP', 'MDVP:Fo(Hz)',
#        'Shimmer:APQ5', 'MDVP:Jitter(%)', 'Shimmer:APQ3'],
#       dtype='object')
# Index(['PPE', 'NHR', 'MDVP:PPQ', 'D2', 'DFA', 'spread1', 'MDVP:Shimmer(dB)',
#        'MDVP:APQ', 'spread2', 'RPDE', 'MDVP:Shimmer', 'HNR', 'MDVP:RAP',
#        'Shimmer:DDA', 'Jitter:DDP', 'Shimmer:APQ5', 'MDVP:Jitter(%)',
#        'Shimmer:APQ3'],
#       dtype='object')
# Index(['spread1', 'MDVP:Shimmer(dB)', 'NHR', 'MDVP:RAP', 'spread2', 'DFA',
#        'MDVP:Shimmer', 'PPE', 'D2', 'RPDE', 'HNR', 'Shimmer:DDA', 'MDVP:APQ',
#        'MDVP:Jitter(%)', 'Jitter:DDP', 'Shimmer:APQ5', 'MDVP:PPQ',
#        'Shimmer:APQ3'],
#       dtype='object')
# Index(['spread1', 'D2', 'PPE', 'MDVP:APQ', 'MDVP:RAP', 'spread2',
#        'MDVP:Shimmer(dB)', 'DFA', 'NHR', 'RPDE', 'MDVP:Shimmer', 'HNR',
#        'Shimmer:DDA', 'MDVP:Jitter(%)', 'Jitter:DDP', 'Shimmer:APQ3',
#        'MDVP:PPQ', 'Shimmer:APQ5'],
#       dtype='object')
# Index(['spread1', 'D2', 'PPE', 'MDVP:APQ', 'MDVP:RAP', 'spread2', 'DFA',
#        'MDVP:Shimmer(dB)', 'MDVP:Shimmer', 'RPDE', 'HNR', 'Shimmer:DDA',
#        'MDVP:PPQ', 'NHR', 'MDVP:Jitter(%)', 'Shimmer:APQ3', 'Jitter:DDP',
#        'Shimmer:APQ5'],
#       dtype='object')
# Index(['spread1', 'D2', 'PPE', 'MDVP:Shimmer', 'DFA', 'spread2',
#        'MDVP:Shimmer(dB)', 'RPDE', 'HNR', 'MDVP:Jitter(%)', 'Shimmer:DDA',
#        'NHR', 'Jitter:DDP', 'MDVP:APQ', 'Shimmer:APQ3', 'MDVP:RAP', 'MDVP:PPQ',
#        'Shimmer:APQ5'],
#       dtype='object')
# Index(['PPE', 'MDVP:Shimmer', 'spread2', 'D2', 'spread1', 'DFA',
#        'MDVP:Shimmer(dB)', 'RPDE', 'HNR', 'MDVP:Jitter(%)', 'Shimmer:DDA',
#        'NHR', 'Jitter:DDP', 'MDVP:APQ', 'Shimmer:APQ3', 'MDVP:PPQ',
#        'Shimmer:APQ5', 'MDVP:RAP'],
#       dtype='object')
# Index(['spread1', 'D2', 'PPE', 'MDVP:Shimmer', 'DFA', 'spread2',
#        'MDVP:Shimmer(dB)', 'RPDE', 'HNR', 'MDVP:Jitter(%)', 'Shimmer:DDA',
#        'NHR', 'Jitter:DDP', 'MDVP:APQ', 'MDVP:PPQ', 'Shimmer:APQ3',
#        'Shimmer:APQ5', 'MDVP:RAP'],
#       dtype='object')
